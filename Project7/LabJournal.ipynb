# %%
import pandas as pd
from pybedtools import BedTool
from pybedtools.featurefuncs import bed2gff

# %% [markdown]
# #### Qiime (Amplicon)
# quality
# ![image.png](attachment:image.png)
#
# filter stats
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Pavian
# ![image-2.png](attachment:image-2.png)
#
#
# ## Metaphlan heatmap
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Edit labels for heatmap

# %%
df = pd.read_csv('metaphlan_merged_species.txt', '\t')
# df.loc[df.sum(axis=1) != 0, :]
def change_column_name(x):
    if x == 'body_site':
        return x
    elif x == 'metaphlan_output':
        return 'Ancient_dental_calculus'
    return x.split('-')[-1].replace('_profile', '')

df.columns = [change_column_name(col) for col in df.columns]
df.to_csv('metaphlan_merged_sp_edited.txt', sep='\t', index=False)

# %% [markdown]
# ### Find intervals that are abset in ancient sample

# %% [markdown]
# #### IGV: alignment + new
# ![image.png](attachment:image.png)
